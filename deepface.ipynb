# %%
pip install deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace

# %%
df = DeepFace.find(img_path = "test2.jpg", db_path = r"C:\Users\asus\Desktop\deepface\workspace")
# Out:
# WARNING: Representations for images in  C:\Users\asus\Desktop\deepface\workspace  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  7  representations found in  representations_vgg_face.pkl
# find function lasts  3.3691632747650146  seconds

# %%
df
# Out:
#                                             identity  VGG-Face_cosine
# 0  C:\Users\asus\Desktop\deepface\workspace/test7...         0.281520
# 1  C:\Users\asus\Desktop\deepface\workspace/test6...         0.317967
# 2  C:\Users\asus\Desktop\deepface\workspace/test3...         0.350243
# 3  C:\Users\asus\Desktop\deepface\workspace/test1...         0.358517
# 4  C:\Users\asus\Desktop\deepface\workspace/test5...         0.379698

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]

#face recognition
df = DeepFace.find(img_path = "test2.jpg", 
          db_path = r"C:\Users\asus\Desktop\deepface\workspace", 
          distance_metric = metrics[1]
)
# Out:
# WARNING: Representations for images in  C:\Users\asus\Desktop\deepface\workspace  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  7  representations found in  representations_vgg_face.pkl
# find function lasts  0.2453467845916748  seconds

# %%
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread(r"C:\Users\asus\Desktop\deepface\workspace\test6.jpg")
imgplot = plt. imshow(img)
plt. show()
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread(r"C:\Users\asus\Desktop\deepface\workspace\test7.jpg")
imgplot = plt. imshow(img)
plt. show()
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread(r"C:\Users\asus\Desktop\deepface\workspace\test3.jpg")
imgplot = plt. imshow(img)
plt. show()
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread(r"C:\Users\asus\Desktop\deepface\workspace\test1.jpg")
imgplot = plt. imshow(img)
plt. show()

df
# Out:
#                                             identity  VGG-Face_euclidean
# 0  C:\Users\asus\Desktop\deepface\workspace/test7...            0.512140
# 1  C:\Users\asus\Desktop\deepface\workspace/test6...            0.518589
# 2  C:\Users\asus\Desktop\deepface\workspace/test3...            0.566268
# 3  C:\Users\asus\Desktop\deepface\workspace/test1...            0.581566

# %%
obj = DeepFace.analyze(img_path = "test2.jpg", 
        actions = ['emotion']
)

# %%
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread('test2.jpg')
imgplot = plt. imshow(img)
plt. show()
obj
# Out:
# {'emotion': {'angry': 3.244267839014662e-05,
#   'disgust': 4.340428275711981e-07,
#   'fear': 0.002443543380777609,
#   'happy': 91.28056712630791,
#   'sad': 0.0021270322935353653,
#   'surprise': 3.892386307681071e-05,
#   'neutral': 8.714790416645432},
#  'dominant_emotion': 'happy',
#  'region': {'x': 232, 'y': 43, 'w': 236, 'h': 236}}

# %%
obj = DeepFace.analyze(img_path = r"C:\Users\asus\Desktop\deepface\workspace\test5.jpg", 
        actions = ['emotion']
)

# %%
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg. imread(r"C:\Users\asus\Desktop\deepface\workspace\test5.jpg")
imgplot = plt. imshow(img)
plt. show()
obj
# Out:
# {'emotion': {'angry': 1.0114486137524636e-06,
#   'disgust': 8.609062653916749e-17,
#   'fear': 99.98862743377686,
#   'happy': 0.011014419578714296,
#   'sad': 0.00032164346066565486,
#   'surprise': 9.53419885263429e-06,
#   'neutral': 2.6806930009115604e-05},
#  'dominant_emotion': 'fear',
#  'region': {'x': 285, 'y': 78, 'w': 229, 'h': 229}}

# %%
vid = DeepFace.stream(db_path = r"C:\Users\asus\Desktop\deepface")
# Out:
# Detector backend is  opencv
# VGG-Face  is built
# Emotion model loaded
# Age model loaded
# Gender model loaded
# Facial attibute analysis models loaded in  2.8801136016845703  seconds
# Finding embedding for test8.jpg: 100%|███████████████████████████████████████████████████| 8/8 [00:02<00:00,  3.76it/s]
# Embeddings found for given data set in  2.129814863204956  seconds

# %%
vid

# %%
# importing libraries
import cv2
import numpy as np
   
# Create a VideoCapture object and read from input file
cap = cv2.VideoCapture('vid.mp4')
   
# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video  file")
   
# Read until video is completed
while(cap.isOpened()):
      
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
   
    # Display the resulting frame
    cv2.imshow('Frame', frame)
   
    # Press Q on keyboard to  exit
    if cv2.waitKey(25) & 0xFF == ord('q'):
      break
   
  # Break the loop
  else: 
    break
   
# When everything done, release 
# the video capture object
cap.release()
   
# Closes all the frames
cv2.destroyAllWindows()
